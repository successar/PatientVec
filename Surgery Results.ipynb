# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from common import *

# %%
keys = ['roc_auc', 'pr_auc']

# %%
yr_df = defaultdict(list)
for yr in [1, 2, 3] :
    for model in ['baselines', 'Basic', 'Attention'] :
        name = os.path.join('outputs/HipSurgery_' + str(yr), model)
        dirs = os.listdir(name)
        dfs = {}
        for d in sorted(dirs) :
            dirname = os.path.join(name, d)
            model_name = get_latest_model(dirname)
            if model_name is not None :
                df = json.load(open(os.path.join(model_name, 'evaluate.json')))
                dfs[d] = {k:v for k, v in df.items() if k in keys}
        
        dfs = pd.DataFrame(dfs).transpose()
        yr_df[yr] += [dfs]
        
    yr_df[yr] = pd.concat(yr_df[yr], axis=0)
yr_df = pd.concat(yr_df.values(), axis=1, keys=yr_df.keys())
yr_df.columns = yr_df.columns.swaplevel(0, 1)
yr_df.sort_index(axis=1, level=0, inplace=True)
display(HTML(yr_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="3" halign="left">pr_auc</th>
#       <th colspan="3" halign="left">roc_auc</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LR+BOW+norm=l2</th>
#       <td>0.415968</td>
#       <td>0.412722</td>
#       <td>0.358760</td>
#       <td>0.819119</td>
#       <td>0.819864</td>
#       <td>0.814649</td>
#     </tr>
#     <tr>
#       <th>LR+TFIDF+norm=l2</th>
#       <td>0.374768</td>
#       <td>0.369283</td>
#       <td>0.356594</td>
#       <td>0.811882</td>
#       <td>0.818131</td>
#       <td>0.815744</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)</th>
#       <td>0.417312</td>
#       <td>0.387561</td>
#       <td>0.356003</td>
#       <td>0.826416</td>
#       <td>0.827678</td>
#       <td>0.807048</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Balanced</th>
#       <td>0.204968</td>
#       <td>0.208214</td>
#       <td>0.228126</td>
#       <td>0.675971</td>
#       <td>0.698623</td>
#       <td>0.703913</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Replicate</th>
#       <td>0.376987</td>
#       <td>0.326726</td>
#       <td>0.337847</td>
#       <td>0.806014</td>
#       <td>0.785779</td>
#       <td>0.825565</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)</th>
#       <td>0.409353</td>
#       <td>0.408185</td>
#       <td>0.420606</td>
#       <td>0.838107</td>
#       <td>0.845982</td>
#       <td>0.846955</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Balanced</th>
#       <td>0.395628</td>
#       <td>0.382900</td>
#       <td>0.376521</td>
#       <td>0.836389</td>
#       <td>0.837164</td>
#       <td>0.840707</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Replicate</th>
#       <td>0.491312</td>
#       <td>0.342371</td>
#       <td>0.398897</td>
#       <td>0.868193</td>
#       <td>0.837712</td>
#       <td>0.815637</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)</th>
#       <td>0.213168</td>
#       <td>0.156853</td>
#       <td>0.122745</td>
#       <td>0.683922</td>
#       <td>0.602846</td>
#       <td>0.579069</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Balanced</th>
#       <td>0.202528</td>
#       <td>0.130490</td>
#       <td>0.118239</td>
#       <td>0.658959</td>
#       <td>0.607179</td>
#       <td>0.545547</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Replicate</th>
#       <td>0.217055</td>
#       <td>0.145382</td>
#       <td>0.147963</td>
#       <td>0.711560</td>
#       <td>0.644820</td>
#       <td>0.621971</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Attention(additive)(hs=128)</th>
#       <td>0.338696</td>
#       <td>0.254872</td>
#       <td>0.372558</td>
#       <td>0.847882</td>
#       <td>0.793791</td>
#       <td>0.810393</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Attention(additive)(hs=128)+Balanced</th>
#       <td>0.333559</td>
#       <td>0.235842</td>
#       <td>0.229315</td>
#       <td>0.800511</td>
#       <td>0.780991</td>
#       <td>0.775943</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)(hs=128)</th>
#       <td>0.273516</td>
#       <td>0.259278</td>
#       <td>0.276672</td>
#       <td>0.794734</td>
#       <td>0.815622</td>
#       <td>0.808006</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)(hs=128)+Balanced</th>
#       <td>0.361447</td>
#       <td>0.289576</td>
#       <td>0.262964</td>
#       <td>0.821673</td>
#       <td>0.828575</td>
#       <td>0.800344</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Attention(additive)(hs=128)</th>
#       <td>0.367419</td>
#       <td>0.404569</td>
#       <td>0.342527</td>
#       <td>0.869379</td>
#       <td>0.852519</td>
#       <td>0.819012</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Attention(additive)(hs=128)+Balanced</th>
#       <td>0.287916</td>
#       <td>0.332147</td>
#       <td>0.264676</td>
#       <td>0.818024</td>
#       <td>0.803734</td>
#       <td>0.798975</td>
#     </tr>
#   </tbody>
# </table>

# %%
yr_df = defaultdict(list)
for yr in [1, 2, 3] :
    for model in ['baselines', 'Basic', 'Attention'] :
        name = os.path.join('outputs/KneeSurgery_' + str(yr), model)
        dirs = os.listdir(name)
        dfs = {}
        for d in sorted(dirs) :
            dirname = os.path.join(name, d)
            model_name = get_latest_model(dirname)
            if model_name is not None :
                df = json.load(open(os.path.join(model_name, 'evaluate.json')))
                dfs[d] = {k:v for k, v in df.items() if k in keys}
        
        dfs = pd.DataFrame(dfs).transpose()
        yr_df[yr] += [dfs]
        
    yr_df[yr] = pd.concat(yr_df[yr], axis=0)
yr_df = pd.concat(yr_df.values(), axis=1, keys=yr_df.keys())
yr_df.columns = yr_df.columns.swaplevel(0, 1)
yr_df.sort_index(axis=1, level=0, inplace=True)
display(HTML(yr_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="3" halign="left">pr_auc</th>
#       <th colspan="3" halign="left">roc_auc</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LR+BOW+norm=l2</th>
#       <td>0.588659</td>
#       <td>0.557406</td>
#       <td>0.548971</td>
#       <td>0.872613</td>
#       <td>0.866329</td>
#       <td>0.871315</td>
#     </tr>
#     <tr>
#       <th>LR+TFIDF+norm=l2</th>
#       <td>0.615401</td>
#       <td>0.578271</td>
#       <td>0.575673</td>
#       <td>0.876429</td>
#       <td>0.877235</td>
#       <td>0.878303</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)</th>
#       <td>0.526643</td>
#       <td>0.458182</td>
#       <td>0.408885</td>
#       <td>0.859654</td>
#       <td>0.855897</td>
#       <td>0.841065</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Balanced</th>
#       <td>0.227744</td>
#       <td>0.277638</td>
#       <td>0.241010</td>
#       <td>0.580201</td>
#       <td>0.664320</td>
#       <td>0.618042</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Replicate</th>
#       <td>0.569735</td>
#       <td>0.515621</td>
#       <td>0.532075</td>
#       <td>0.865981</td>
#       <td>0.864921</td>
#       <td>0.888624</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)</th>
#       <td>0.527170</td>
#       <td>0.539622</td>
#       <td>0.512994</td>
#       <td>0.864904</td>
#       <td>0.851047</td>
#       <td>0.868805</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Balanced</th>
#       <td>0.544662</td>
#       <td>0.551618</td>
#       <td>0.518133</td>
#       <td>0.878566</td>
#       <td>0.879134</td>
#       <td>0.861486</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Replicate</th>
#       <td>0.562954</td>
#       <td>0.496757</td>
#       <td>0.503984</td>
#       <td>0.881433</td>
#       <td>0.859493</td>
#       <td>0.867177</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)</th>
#       <td>0.138312</td>
#       <td>0.109922</td>
#       <td>0.148654</td>
#       <td>0.617889</td>
#       <td>0.509863</td>
#       <td>0.590208</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Balanced</th>
#       <td>0.140118</td>
#       <td>0.122860</td>
#       <td>0.149692</td>
#       <td>0.610341</td>
#       <td>0.583644</td>
#       <td>0.590115</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Replicate</th>
#       <td>0.260374</td>
#       <td>0.239076</td>
#       <td>0.255083</td>
#       <td>0.748524</td>
#       <td>0.767275</td>
#       <td>0.737423</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Attention(additive)(hs=128)</th>
#       <td>0.584225</td>
#       <td>0.560217</td>
#       <td>0.543080</td>
#       <td>0.882891</td>
#       <td>0.881102</td>
#       <td>0.871570</td>
#     </tr>
#     <tr>
#       <th>Average(hs=256)+Attention(additive)(hs=128)+Balanced</th>
#       <td>0.565547</td>
#       <td>0.505809</td>
#       <td>0.506316</td>
#       <td>0.860044</td>
#       <td>0.859968</td>
#       <td>0.870018</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)(hs=128)</th>
#       <td>0.633362</td>
#       <td>0.556960</td>
#       <td>0.568251</td>
#       <td>0.899954</td>
#       <td>0.861172</td>
#       <td>0.876522</td>
#     </tr>
#     <tr>
#       <th>CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)(hs=128)+Balanced</th>
#       <td>0.525159</td>
#       <td>0.556042</td>
#       <td>0.535754</td>
#       <td>0.881025</td>
#       <td>0.857305</td>
#       <td>0.867685</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Attention(additive)(hs=128)</th>
#       <td>0.596392</td>
#       <td>0.552613</td>
#       <td>0.518410</td>
#       <td>0.881602</td>
#       <td>0.875140</td>
#       <td>0.864989</td>
#     </tr>
#     <tr>
#       <th>LSTM(hs=128)+Attention(additive)(hs=128)+Balanced</th>
#       <td>0.528426</td>
#       <td>0.582046</td>
#       <td>0.526885</td>
#       <td>0.853955</td>
#       <td>0.868076</td>
#       <td>0.869059</td>
#     </tr>
#   </tbody>
# </table>

# %%
def filter_results(pattern) :
    return yr_df.filter(regex=pattern, axis=0)

# %%
filter_results(r'LSTM+')
# Out:
#                                                      pr_auc            \
#                                                           1         2
# LSTM(hs=128)                                       0.138312  0.109922
# LSTM(hs=128)+Balanced                              0.140118  0.122860
# LSTM(hs=128)+Replicate                             0.260374  0.239076
# LSTM(hs=128)+Attention(additive)(hs=128)           0.596392  0.552613
# LSTM(hs=128)+Attention(additive)(hs=128)+Balanced  0.528426  0.582046
#
#                                                               roc_auc  \
#                                                           3         1
# LSTM(hs=128)                                       0.148654  0.617889
# LSTM(hs=128)+Balanced                              0.149692  0.610341
# LSTM(hs=128)+Replicate                             0.255083  0.748524
# LSTM(hs=128)+Attention(additive)(hs=128)           0.518410  0.881602
# LSTM(hs=128)+Attention(additive)(hs=128)+Balanced  0.526885  0.853955
#
#
#                                                           2         3
# LSTM(hs=128)                                       0.509863  0.590208
# LSTM(hs=128)+Balanced                              0.583644  0.590115
# LSTM(hs=128)+Replicate                             0.767275  0.737423
# LSTM(hs=128)+Attention(additive)(hs=128)           0.875140  0.864989
# LSTM(hs=128)+Attention(additive)(hs=128)+Balanced  0.868076  0.869059

# %%
filter_results(r'Average+')
# Out:
#                                                       pr_auc            \
#                                                            1         2
# Average(hs=256)                                     0.526643  0.458182
# Average(hs=256)+Balanced                            0.227744  0.277638
# Average(hs=256)+Replicate                           0.569735  0.515621
# Average(hs=256)+Attention(additive)(hs=128)         0.584225  0.560217
# Average(hs=256)+Attention(additive)(hs=128)+Bal...  0.565547  0.505809
#
#                                                                roc_auc  \
#                                                            3         1
# Average(hs=256)                                     0.408885  0.859654
# Average(hs=256)+Balanced                            0.241010  0.580201
# Average(hs=256)+Replicate                           0.532075  0.865981
# Average(hs=256)+Attention(additive)(hs=128)         0.543080  0.882891
# Average(hs=256)+Attention(additive)(hs=128)+Bal...  0.506316  0.860044
#
#
#                                                            2         3
# Average(hs=256)                                     0.855897  0.841065
# Average(hs=256)+Balanced                            0.664320  0.618042
# Average(hs=256)+Replicate                           0.864921  0.888624
# Average(hs=256)+Attention(additive)(hs=128)         0.881102  0.871570
# Average(hs=256)+Attention(additive)(hs=128)+Bal...  0.859968  0.870018

# %%
filter_results(r'CNN+')
# Out:
#                                                       pr_auc            \
#                                                            1         2
# CNN(hs=64)(kernels=3,5,7,9)                         0.527170  0.539622
# CNN(hs=64)(kernels=3,5,7,9)+Balanced                0.544662  0.551618
# CNN(hs=64)(kernels=3,5,7,9)+Replicate               0.562954  0.496757
# CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)...  0.633362  0.556960
# CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)...  0.525159  0.556042
#
#                                                                roc_auc  \
#                                                            3         1
# CNN(hs=64)(kernels=3,5,7,9)                         0.512994  0.864904
# CNN(hs=64)(kernels=3,5,7,9)+Balanced                0.518133  0.878566
# CNN(hs=64)(kernels=3,5,7,9)+Replicate               0.503984  0.881433
# CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)...  0.568251  0.899954
# CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)...  0.535754  0.881025
#
#
#                                                            2         3
# CNN(hs=64)(kernels=3,5,7,9)                         0.851047  0.868805
# CNN(hs=64)(kernels=3,5,7,9)+Balanced                0.879134  0.861486
# CNN(hs=64)(kernels=3,5,7,9)+Replicate               0.859493  0.867177
# CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)...  0.861172  0.876522
# CNN(hs=64)(kernels=3,5,7,9)+Attention(additive)...  0.857305  0.867685

# %%
filter_results(r'LR+')
# Out:
#                     pr_auc                       roc_auc
#                          1         2         3         1         2         3
# LR+BOW+norm=l2    0.588659  0.557406  0.548971  0.872613  0.866329  0.871315
# LR+TFIDF+norm=l2  0.615401  0.578271  0.575673  0.876429  0.877235  0.878303
